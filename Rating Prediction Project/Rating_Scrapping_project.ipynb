# %% [markdown]
# # Problem Staement:
# We have to scrap reviews and ratings for different products like laptop,headphones, smart watches, monitor, router,phone, home theatres, printers etc from multiple online websites.

# %% [markdown]
# # Scrapping Headphone Reviews and Ratings from Amazon

# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import *
import time
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
driver = webdriver.Chrome(r"C:/Users/swati/Downloads/chromedriver_win32 (2)/chromedriver.exe")

# %%
driver.maximize_window()

# %%
driver.get("https://www.amazon.in/")

# %%
search_bar = driver.find_element_by_xpath("//input[@id='twotabsearchtextbox']")
search_bar.send_keys("headphones")

# %%
search_click = driver.find_element_by_xpath("//input[@id='nav-search-submit-button']")
search_click.click()

# %%
# Creating empty lists
Product_URL=[]
Ratings=[]
Review=[]

#Getting URLs of the product
for i in range(1,4):
    URL = driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in URL:
        Product_URL.append(i.get_attribute('href'))
      
    try:
        next_btn=driver.find_element_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]').click()
    except NoSuchElementException:
        pass
    
for i in Product_URL:
    driver.get(i)
    
    # Clicking the rating
    try:
        driver.find_element_by_xpath("//a[1][@id='acrCustomerReviewLink']").click()
    except NoSuchElementException:
        print("No rating")
        pass
    
    #Clicking to see all reviews
    try:
        driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()
    except NoSuchElementException:
        pass
    
    #Scrapping the details
    Start_page=1
    End_page=50
    for page in range(Start_page,End_page+1):
        try:
            Reviews=driver.find_elements_by_xpath("//div[@class='a-row a-spacing-small review-data']/span/span")
            for r in Reviews:
                Review.append(r.text.replace('\n',''))
        except NoSuchElementException:
            Review.append("Not Available")
        try:
            Rating=driver.find_elements_by_xpath("//div[@class='a-section celwidget']/div[2]/a[1]")
            for i in Rating:
                rating=i.get_attribute('title')
                Ratings.append(rating[:3])
        except NoSuchElementException:
            Ratings.append("Not available")      
        
        #Looping for going to next page automatically
        try:
            next_page=driver.find_element_by_xpath("//div[@id='cm_cr-pagination_bar']/ul/li[2]/a")
            if next_page.text=='Next Page':
                next_page.click()
                time.sleep(2)
        except NoSuchElementException:
            pass
# Out:
# No rating

# %%
print(len(Review),len(Ratings))
# Out:
# 13100 13000

# %%
headphones=pd.DataFrame({'Product_Review':Review[:13000],'Ratings':Ratings[:13000]})
headphones
# Out:
#                                           Product_Review Ratings
# 0      Why are there two Boat Rockerz 450? One is pri...     1.0
# 1      I'm writing this review after using it for ove...     5.0
# 2      - Good looks- sturdy- Good built quality- fits...     5.0
# 3      After 25 days of useage I am writing my review...     5.0
# 4      The product is of very poor quality. I bought ...     1.0
# ...                                                  ...     ...
# 12995  exactly after 30-32 days,mic problem, in-line ...     1.0
# 12996  I had just got this headphones day before yest...     1.0
# 12997  I got this headphone for 599.the build quality...     4.0
# 12998  Please don't purchase this product. The one si...     1.0
# 12999         Awesome Sound but jack is not gold plated!     4.0
#
# [13000 rows x 2 columns]

# %% [markdown]
# # Scrapping Laptop ratings and Reviews from Amazon

# %%
driver.get("https://www.amazon.in/")

# %%
search_bar = driver.find_element_by_xpath("//input[@id='twotabsearchtextbox']")
search_bar.send_keys("laptops")

# %%
search_click = driver.find_element_by_xpath("//input[@id='nav-search-submit-button']")
search_click.click()

# %%
# Creating empty lists
Product_URL=[]
Ratings=[]
Review=[]

#Getting URLs of the product
for i in range(1,4):
    URL = driver.find_elements_by_xpath("//a[@class='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")
    for i in URL:
        Product_URL.append(i.get_attribute('href'))
      
    try:
        next_btn=driver.find_element_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]').click()
    except NoSuchElementException:
        pass
    
for i in Product_URL:
    driver.get(i)
    
    # Clicking the rating
    try:
        driver.find_element_by_xpath("//a[1][@id='acrCustomerReviewLink']").click()
    except NoSuchElementException:
        print("No rating")
        pass
    
    #Clicking to see all reviews
    try:
        driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()
    except NoSuchElementException:
        pass
    
    #Scrapping the details
    Start_page=1
    End_page=50
    for page in range(Start_page,End_page+1):
        try:
            Reviews=driver.find_elements_by_xpath("//div[@class='a-row a-spacing-small review-data']/span/span")
            for r in Reviews:
                Review.append(r.text.replace('\n',''))
        except NoSuchElementException:
            Review.append("Not Available")
        try:
            Rating=driver.find_elements_by_xpath("//div[@class='a-section celwidget']/div[2]/a[1]")
            for i in Rating:
                rating=i.get_attribute('title')
                Ratings.append(rating[:3])
        except NoSuchElementException:
            Ratings.append("Not available")      
        
        #Looping for going to next page automatically
        try:
            next_page=driver.find_element_by_xpath("//div[@id='cm_cr-pagination_bar']/ul/li[2]/a")
            if next_page.text=='Next Page':
                next_page.click()
                time.sleep(2)
        except NoSuchElementException:
            pass
# Out:
# No rating

# %%
print(len(Review),len(Ratings))
# Out:
# 11200 11350

# %%
laptops=pd.DataFrame({'Product_Review':Review[:11200],'Ratings':Ratings[:11200]})
laptops
# Out:
#                                           Product_Review Ratings
# 0      Best laptop for WFH use. Best keyboard,display...     4.0
# 1      Sleek And Good Build QualityFast, Precise and ...     5.0
# 2      Good laptop but some pieces are faulty for mic...     5.0
# 3      Product is good but Amazon's hidden policy mig...     2.0
# 4      Even upon contacting Lenovo support, issue is ...     1.0
# ...                                                  ...     ...
# 11195  It's not playing 4k videoCharging adaptor is h...     4.0
# 11196  booting time is crazy , best for students , go...     5.0
# 11197  Today I have received my Laptop today. Look is...     5.0
# 11198  Good build quality, processor & operating syst...     4.0
# 11199  Overall its a good laptop. You get what you ha...     3.0
#
# [11200 rows x 2 columns]

# %% [markdown]
# # Scrapping Ratings and Reviews for Phone from Amazon

# %%
driver.get("https://www.amazon.in/")

# %%
search_bar = driver.find_element_by_xpath("//input[@id='twotabsearchtextbox']")
search_bar.send_keys("phone")

# %%
search_click = driver.find_element_by_xpath("//input[@id='nav-search-submit-button']")
search_click.click()

# %%
# Creating empty lists
Product_URL=[]
Ratings=[]
Review=[]

#Getting URLs of the product
for i in range(1,4):
    URL = driver.find_elements_by_xpath("//a[@class='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")
    for i in URL:
        Product_URL.append(i.get_attribute('href'))
      
    try:
        next_btn=driver.find_element_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]').click()
    except NoSuchElementException:
        pass
    
for i in Product_URL:
    driver.get(i)
    
    # Clicking the rating
    try:
        driver.find_element_by_xpath("//a[1][@id='acrCustomerReviewLink']").click()
    except NoSuchElementException:
        print("No rating")
        pass
    
    #Clicking to see all reviews
    try:
        driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()
    except NoSuchElementException:
        pass
    
    #Scrapping the details
    Start_page=1
    End_page=50
    for page in range(Start_page,End_page+1):
        try:
            Reviews=driver.find_elements_by_xpath("//div[@class='a-row a-spacing-small review-data']/span/span")
            for r in Reviews:
                Review.append(r.text.replace('\n',''))
        except NoSuchElementException:
            Review.append("Not Available")
        try:
            Rating=driver.find_elements_by_xpath("//div[@class='a-section celwidget']/div[2]/a[1]")
            for i in Rating:
                rating=i.get_attribute('title')
                Ratings.append(rating[:3])
        except NoSuchElementException:
            Ratings.append("Not available")      
        
        #Looping for going to next page automatically
        try:
            next_page=driver.find_element_by_xpath("//div[@id='cm_cr-pagination_bar']/ul/li[2]/a")
            if next_page.text=='Next Page':
                next_page.click()
                time.sleep(2)
        except NoSuchElementException:
            pass
# Out:
# No rating
# No rating

# %%
print(len(Review),len(Ratings))
# Out:
# 10850 11050

# %%
phones = pd.DataFrame({'Product_Review':Review[:10850],'Ratings':Ratings[:10850]})
phones
# Out:
#                                           Product_Review Ratings
# 0      My First impression of the price 18K and featu...     5.0
# 1      I prebooked Lava Agni 5G. and paid through ama...     5.0
# 2      Product is o.k.but internet connection,a littl...     4.0
# 3       You'll be surprised to see how good LAVA Agni...     5.0
# 4      I always prefer to buy nonchinese products. I ...     5.0
# ...                                                  ...     ...
# 10845  Never thought of getting so many features at t...     1.0
# 10846  Never thought of getting so many features at t...     5.0
# 10847  Never thought of getting so many features at t...     4.0
# 10848  Never thought of getting so many features at t...     1.0
# 10849  Never thought of getting so many features at t...     1.0
#
# [10850 rows x 2 columns]

# %% [markdown]
# # Scrapping ratings and reviews for Smart Watches from Amazon

# %%
driver.get("https://www.amazon.in/")

# %%
search_bar = driver.find_element_by_xpath("//input[@id='twotabsearchtextbox']")
search_bar.send_keys("smart watches")

# %%
search_click = driver.find_element_by_xpath("//input[@id='nav-search-submit-button']")
search_click.click()

# %%
# Creating empty lists
Product_URL=[]
Ratings=[]
Review=[]

#Getting URLs of the product
for i in range(1,4):
    URL = driver.find_elements_by_xpath("//a[@class='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")
    for i in URL:
        Product_URL.append(i.get_attribute('href'))
      
    try:
        next_btn=driver.find_element_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]').click()
    except NoSuchElementException:
        pass
    
for i in Product_URL:
    driver.get(i)
    
    # Clicking the rating
    try:
        driver.find_element_by_xpath("//a[1][@id='acrCustomerReviewLink']").click()
    except NoSuchElementException:
        print("No rating")
        pass
    
    #Clicking to see all reviews
    try:
        driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()
    except NoSuchElementException:
        pass
    
    #Scrapping the details
    Start_page=1
    End_page=50
    for page in range(Start_page,End_page+1):
        try:
            Reviews=driver.find_elements_by_xpath("//div[@class='a-row a-spacing-small review-data']/span/span")
            for r in Reviews:
                Review.append(r.text.replace('\n',''))
        except NoSuchElementException:
            Review.append("Not Available")
        try:
            Rating=driver.find_elements_by_xpath("//div[@class='a-section celwidget']/div[2]/a[1]")
            for i in Rating:
                rating=i.get_attribute('title')
                Ratings.append(rating[:3])
        except NoSuchElementException:
            Ratings.append("Not available")      
        
        #Looping for going to next page automatically
        try:
            next_page=driver.find_element_by_xpath("//div[@id='cm_cr-pagination_bar']/ul/li[2]/a")
            if next_page.text=='Next Page':
                next_page.click()
                time.sleep(2)
        except NoSuchElementException:
            pass

# %%
print(len(Review),len(Ratings))
# Out:
# 12900 13000

# %%
smart_watches = pd.DataFrame({'Product_Review':Review[:12900],'Ratings':Ratings[:12900]})
smart_watches
# Out:
#                                           Product_Review Ratings
# 0      I am changing review after using Ninja calling...     5.0
# 1      Bought for my sister. Watch is good looking an...     5.0
# 2      Overall product is good.. Perfectly working al...     5.0
# 3                                                   Good     5.0
# 4      watch and dont work properly so do not buy thi...     1.0
# ...                                                  ...     ...
# 12895  Build up quality is better but functioning not...     1.0
# 12896  Excellent watchPros-Looks premium-Display is s...     1.0
# 12897  Well design & fast performance, equal to amole...     5.0
# 12898  Fantastic display quality is super design buil...     5.0
# 12899   Display is smooth & attractive. All the funct...     5.0
#
# [12900 rows x 2 columns]

# %% [markdown]
# # Scrapping ratings and reviews for HomeTheatre from Amazon

# %%
driver.get("https://www.amazon.in/")

# %%
search_bar = driver.find_element_by_xpath("//input[@id='twotabsearchtextbox']")
search_bar.send_keys("Home theatre")

# %%
search_click = driver.find_element_by_xpath("//input[@id='nav-search-submit-button']")
search_click.click()

# %%
Product_URL=[]
Ratings=[]
Review=[]

#Getting URLs of the product
for i in range(1,4):
    URL = driver.find_elements_by_xpath("//a[@class='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")
    for i in URL:
        Product_URL.append(i.get_attribute('href'))
      
    try:
        next_btn=driver.find_element_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]').click()
    except NoSuchElementException:
        pass
    
for i in Product_URL:
    driver.get(i)
    
    # Clicking the rating
    try:
        driver.find_element_by_xpath("//a[1][@id='acrCustomerReviewLink']").click()
    except NoSuchElementException:
        print("No rating")
        pass
    
    #Clicking to see all reviews
    try:
        driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()
    except NoSuchElementException:
        pass
    
    #Scrapping the details
    Start_page=1
    End_page=50
    for page in range(Start_page,End_page+1):
        try:
            Reviews=driver.find_elements_by_xpath("//div[@class='a-row a-spacing-small review-data']/span/span")
            for r in Reviews:
                Review.append(r.text.replace('\n',''))
        except NoSuchElementException:
            Review.append("Not Available")
        try:
            Rating=driver.find_elements_by_xpath("//div[@class='a-section celwidget']/div[2]/a[1]")
            for i in Rating:
                rating=i.get_attribute('title')
                Ratings.append(rating[:3])
        except NoSuchElementException:
            Ratings.append("Not available")      
        
        #Looping for going to next page automatically
        try:
            next_page=driver.find_element_by_xpath("//div[@id='cm_cr-pagination_bar']/ul/li[2]/a")
            if next_page.text=='Next Page':
                next_page.click()
                time.sleep(2)
        except NoSuchElementException:
            pass

# %%
print(len(Review),len(Ratings))
# Out:
# 11800 11900

# %%
Home_Theatre = pd.DataFrame({'Product_Review':Review[:11800],'Ratings':Ratings[:11800]})
Home_Theatre
# Out:
#                                           Product_Review Ratings
# 0      Please dont buy this item at all. I ordered it...     1.0
# 1       This Philips home theatre 5.1 is very much po...     5.0
# 2      Very good product but This speaker doesn't con...     3.0
# 3      I would actually give this an overall rating o...     4.0
# 4      Lets Discuss what all sources available in thi...     4.0
# ...                                                  ...     ...
# 11795   Don't buy philips home theatre this is not St...     1.0
# 11796  ProsBest in budget rangeBass is excellentFor b...     5.0
# 11797  Bought with two offers at 5699/-. Got the prod...     3.0
# 11798  The product is good for the price but to use a...     4.0
# 11799  Product is good but service is completely bad....     1.0
#
# [11800 rows x 2 columns]

# %% [markdown]
# # Scrapping ratings and reviews for Router from FlipKart

# %%
## getting the driver to review page:-
driver.get('https://www.flipkart.com/tp-link-tl-wr841n-300mbps-wireless-n-router/product-reviews/itmf48vgyfyx8m4f?pid=RTRD7HN3JJYF6WN2&lid=LSTRTRD7HN3JJYF6WN20ZITXQ&marketplace=FLIPKART')

# %%
#Taking the empty lists
Ratings=[]
Review=[]

#Now we will take a for loop and scrap
for i in range(0,150):
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']"):
        Ratings.append(j.text)
    for j in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Review.append(j.text)
        
    #Path for next page as it changes for every page. We are appending numbers as pages change  
    k=i+1
    next_page="https://www.flipkart.com/tp-link-tl-wr841n-300mbps-wireless-n-router/product-reviews/itmf48vgyfyx8m4f?pid=RTRD7HN3JJYF6WN2&lid=LSTRTRD7HN3JJYF6WN20ZITXQ&marketplace=FLIPKART&page="+str(k) 
    driver.get(next_page)

# %%
print(len(Review),len(Ratings))
# Out:
# 1180 1147

# %%
routers = pd.DataFrame({'Product_Review':Review[:1147], 'Ratings' : Ratings[:1147]})
routers
# Out:
#                                          Product_Review Ratings
# 0     After careful consideration of similar prodcut...       5
# 1     A budget router, with 5dbi antenna...what more...       5
# 2     It is really great product and customer suppor...       5
# 3     if you are looking for a budget router its you...       5
# 4     A bit too late to write a review I guess.. Bou...       5
# ...                                                 ...     ...
# 1142  Just one word - Great! Before buying this rout...       4
# 1143  After so many time spent on net for searching ...       4
# 1144  I was looking for a WiFi router for home purpo...       4
# 1145  I buyed this product from Flipkart, this guys ...       4
# 1146  i purchased this router last week from flipkar...       5
#
# [1147 rows x 2 columns]

# %% [markdown]
# # Scrapping  ratings and reviews for Printers from FlipKart

# %%
driver.get("https://www.flipkart.com/search?q=printer&sid=6bo%2Ctia%2Cffn%2Ct64%2Cmpr&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_na&as-pos=1&as-type=RECENT&suggestionId=printer%7CMulti+Function+Printers&requestId=2bc3ed4e-634b-428b-84e0-c968ac97c8b9&as-searchtext=printers")

# %%
#Taking the empty lists
Ratings=[]
Review=[]

#Now we will take a for loop and scrap
for i in range(0,150):
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']"):
        Ratings.append(j.text)
    for j in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Review.append(j.text)
        
    #Path for next page as it changes for every page. We are appending numbers as pages change  
    k=i+1
    next_page="https://www.flipkart.com/canon-g2012-multi-function-color-printer-color-page-cost-0-32-rs-black-0-09-rs/product-reviews/itmf2qc6srhervwt?pid=PRNFZZWTHNSR5UM7&lid=LSTPRNFZZWTHNSR5UM7MBGUWM&marketplace=FLIPKART&page="+str(k)    
    driver.get(next_page)

# %%
print(len(Ratings), len(Review))
# Out:
# 201 220

# %%
printers = pd.DataFrame({'Product_Review':Review[:201], 'Ratings' : Ratings[:201]})
printers
# Out:
#                                         Product_Review Ratings
# 0    see, i am the one who thought a lot before get...       5
# 1    On 29th of March, this product delivered to me...       5
# 2      Very beautiful and workable printer love it....       5
# 3    The printer rollers are not working properly a...       5
# 4    I bought this printer after reviewing many oth...       5
# ..                                                 ...     ...
# 196        This is one best printer for small business       5
# 197                                          Very good       5
# 198                                       Good printer       4
# 199                                          Excellent       5
# 200                      Good product & easy to use...       5
#
# [201 rows x 2 columns]

# %% [markdown]
# # Scrapping ratings and reviews for monitor from Flipkart

# %%
driver.get("https://www.flipkart.com/lg-24-inch-full-hd-led-backlit-ips-panel-white-colour-monitor-24mk600m/p/itmfb6jq2jgffrtj?pid=MONFB6JQFJEP7BZX&marketplace=FLIPKART")

# %%
#Taking the empty lists
Ratings=[]
Review=[]

#Now we will take a for loop and scrap
for i in range(0,150):
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']"):
        Ratings.append(j.text)
    for j in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Review.append(j.text)
        
    #Path for next page as it changes for every page. We are appending numbers as pages change  
    k=i+1
    next_page="https://www.flipkart.com/lg-24-inch-full-hd-led-backlit-ips-panel-white-colour-monitor-24mk600m/product-reviews/itmfb6jq2jgffrtj?pid=MONFB6JQFJEP7BZX&lid=LSTMONFB6JQFJEP7BZXLEIFM1&marketplace=FLIPKART&page="+str(k)    
    driver.get(next_page)

# %%
print(len(Ratings), len(Review))
# Out:
# 838 890

# %%
monitors = pd.DataFrame({'Product_Review':Review[:838], 'Ratings' : Ratings[:838]})
monitors
# Out:
#                                         Product_Review Ratings
# 0    I bought this monitor after so much research o...       5
# 1    Monitor is great on its own but it wasn't a wo...       4
# 2    Color = 99%\nBlack = 70%\nThis monitor is bett...       4
# 3    Pros: good price to quality ratio if you get i...       5
# 4    Nice monitor features are fully loaded.\nPros\...       4
# ..                                                 ...     ...
# 833                 Speaker option is not available...       4
# 834  Quite satisfied, Good monitor for regular usag...       4
# 835                very nice monitor must buy friends.       5
# 836             Excellent product. I am 100% satisfied       3
# 837  Best Monitor, Full HD IPS, 22 INCH, TWO HDMI P...       5
#
# [838 rows x 2 columns]

# %%
# Combining all dataframes into a single dataframe
ratings_data=headphones.append([laptops,phones,smart_watches,Home_Theatre,routers,printers,monitors],ignore_index=True)
ratings_data
# Out:
#                                           Product_Review Ratings
# 0      Why are there two Boat Rockerz 450? One is pri...     1.0
# 1      I'm writing this review after using it for ove...     5.0
# 2      - Good looks- sturdy- Good built quality- fits...     5.0
# 3      After 25 days of useage I am writing my review...     5.0
# 4      The product is of very poor quality. I bought ...     1.0
# ...                                                  ...     ...
# 61931                 Speaker option is not available...       4
# 61932  Quite satisfied, Good monitor for regular usag...       4
# 61933                very nice monitor must buy friends.       5
# 61934             Excellent product. I am 100% satisfied       3
# 61935  Best Monitor, Full HD IPS, 22 INCH, TWO HDMI P...       5
#
# [61936 rows x 2 columns]

# %%
ratings_data.to_csv("Rating_Scrapping_data.csv")

# %%
driver.close()
